# %% [markdown]
# # Batch Run
#
# ### Description
# Perform field detection on a list of files, then write the results on a json file. It contains coordinates of the bounding box, which could be then used to crop out the handwriting

# %% [markdown]
# ## Arguments
# - Metadata file: [*.data file]
# - Config file: [*.cfg file]
# - Weights file: *[.weights]
# - Output file: [*.json]
# - File list: [*.txt]
#
# ## Output File
# - Field Name
# - Center X coordinate
# - Center Y coordinate
# - Height
# - Width

# %%
# !darknet/darknet detector test obj-23f-b2.data  yolov3-tiny-23f-b2-832.cfg  backup/yolov3-tiny-23f-b2-832_last.weights -iou_thresh 0.70 -ext_output -dont_show -out result_rwdata_70iou.json <  rwdata_info.txt
# Out:
# Cannot load image "data/labels/32_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/33_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/34_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/35_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/36_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/37_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/38_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/39_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/40_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/41_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/42_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/43_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/44_0.png"
# STB Reason: can't fopen
# Cannot load image "data/labels/45_0.png"
# STB Reason: can't fopen
# ...
